# %% [markdown]
# <a href="https://colab.research.google.com/github/LuminaX-alt/Women-safety-device/blob/main/call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyttsx3

# %%
# !sudo apt-get update && sudo apt-get install espeak -y # Install espeak
# !pip install pyttsx3 # Installs pyttsx3 for text to speech

import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client

# Text-to-speech initialization, specifying espeak as the engine
def speak(message):
    engine = pyttsx3.init('espeak') # Initialize pyttsx3 with espeak engine
    engine.say(message)
    engine.runAndWait()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,630 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,614 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !sudo apt-get update && sudo apt-get install espeak -y # Install espeak
# !pip install pyttsx3 # Installs pyttsx3 for text to speech
# !pip install SpeechRecognition pyaudio geopy twilio

import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client

# Text-to-speech initialization, specifying espeak as the engine
def speak(message):
    engine = pyttsx3.init('espeak')  # Initialize pyttsx3 with espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the current location
def get_location():
    geolocator = Nominatim(user_agent="women_safety_device")
    # Get current location using IP address
    location = geolocator.geocode("Your current location")
    # Get latitude and longitude
    if location:  # added this condition check for location
        return location.latitude, location.longitude
    else:
        print("Unable to retrieve location using IP. Enter manually:")
        latitude = float(input("Enter Latitude: "))
        longitude = float(input("Enter Longitude: "))
        return latitude, longitude

# Function to send an SMS alert
def send_alert_message(location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)

    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]}"

    for contact in contacts:
        message = client.messages.create(
            body=message_body,
            from_="+12183092954",  # Replace with your Twilio phone number
            to=contact
        )
        print(f"Message sent to {contact}: {message.sid}")

# Function to detect the voice command
def detect_voice_command():
    recognizer = sr.Recognizer()

    # Try to find the desired microphone by name
    try:
        # Get a list of all available microphones
        microphone_names = sr.Microphone.list_microphone_names()

        # Iterate through the microphones and select the desired one
        for index, name in enumerate(microphone_names):
            if "OnePlus Nord Buds 2r" in name:  # Replace with your actual microphone name
                device_index = index
                break
        else:  # If loop completes without finding the desired microphone
            device_index = None  # Use the default microphone
            print("Microphone not found. Using default.")

        # Create a microphone instance with the selected device index
        with sr.Microphone(device_index=device_index) as source:
            # Properly indented code block within 'with' statement
            speak("Listening for help command...")
            try:
                audio = recognizer.listen(source, timeout=10)
                command = recognizer.recognize_google(audio).lower()
                return command
            except sr.UnknownValueError:
                print("Could not understand audio")
                return None
            except sr.RequestError as e:
                print(f"Could not request results from Google Speech Recognition service; {e}")
                return None

    except OSError as e:
        # Handle the case where no microphone is available or accessible
        if "No Default Input Device Available" in str(e):
            print("Error: No microphone found. Please connect a microphone and try again.")
            return None  # Return None to indicate failure
        else:
            raise  # Re-raise the exception for other errors


# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    command = detect_voice_command()

    if command == "help help help":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()

        if user_response == "yes":
            location = get_location()
            send_alert_message(location, emergency_contacts)
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition # Removed the extra indent
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 5.1 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !pip install speech_recognition
# Out:
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
RECORD = """
   const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
   const b2text = blob => new Promise(resolve => {
     const reader = new FileReader()
     reader.onloadend = e => resolve(e.srcElement.result)
     reader.readAsDataURL(blob)
   })
   var record = time => new Promise(async resolve => {
     stream = await navigator.mediaDevices.getUserMedia({ audio: true })
     recorder = new MediaRecorder(stream)
     chunks = []
     recorder.ondataavailable = e => chunks.push(e.data)
     recorder.start()
     await sleep(time)
     recorder.onstop = async ()=>{
       blob = new Blob(chunks)
       text = await b2text(blob)
       resolve(text)
     }
     recorder.stop()
   })
   """

def record(sec=3): # Fixed: Removed extra indent here
    display(IPython.display.Javascript(RECORD))
    s = output.eval_js('record(%d)' % (sec*1000))
    b = base64.b64decode(s.split(',')[1])
    with open('audio.wav','wb') as f:
        f.write(b)
    return 'audio.wav'

# %%
def detect_voice_command():
       recognizer = sr.Recognizer()

       # Record audio using your phone:
       audio_file = record()

       # Load the audio file:
       with sr.AudioFile(audio_file) as source:
           audio = recognizer.record(source)

       # Recognize speech:
       try:
           command = recognizer.recognize_google(audio).lower()
           return command
       except sr.UnknownValueError:
           print("Could not understand audio")
           return None
       except sr.RequestError as e:
           print(f"Could not request results from Google Speech Recognition service; {e}")
           return None

# %%
# !pip install SpeechRecognition # Install (or reinstall) the SpeechRecognition library
# !pip install pyaudio
# !pip install ipywebrtc
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr # Now, the import should work
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the current location
def get_location():
    geolocator = Nominatim(user_agent="women_safety_device")
    # Get current location using IP address
    location = geolocator.geocode("Your current location")
    # Get latitude and longitude
    if location:
        return location.latitude, location.longitude
    else:
        print("Unable to retrieve location using IP. Enter manually:")
        latitude = float(input("Enter Latitude: "))
        longitude = float(input("Enter Longitude: "))
        return latitude, longitude

# Function to send an SMS alert
def send_alert_message(location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)

    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]}"

    for contact in contacts:
        message = client.messages.create(
            body=message_body,
            from_="+12183092954",  # Replace with your Twilio phone number
            to=contact
        )
        print(f"Message sent to {contact}: {message.sid}")

# Function to record audio from the phone's microphone
RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
  display(IPython.display.Javascript(RECORD))
  s = output.eval_js('record(%d)' % (sec*1000))
  b = base64.b64decode(s.split(',')[1])
  with open('audio.wav','wb') as f:
    f.write(b)
  return 'audio.wav'

# Function to detect the voice command
def detect_voice_command():
    recognizer = sr.Recognizer()

    # Record audio using your phone:
    audio_file = record()

    # Load the audio file:
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)

    # Recognize speech:
    try:
        command = recognizer.recognize_google(audio).lower()
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    command = detect_voice_command()

    if command == "help help help":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()

        if user_response == "yes":
            location = get_location()
            send_alert_message(location, emergency_contacts)
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)
# ...
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/speech_recognition/__init__.py in __enter__(self)
#     232             # attempt to read the file as WAV
# ...

# %%
# !pip install pydub

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket  # Import for IP address lookup


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the current location automatically
def get_location():
    geolocator = Nominatim(user_agent="women_safety_device")

    try:
        # Get the public IP address
        hostname = socket.gethostname()
        ip_address = socket.gethostbyname(hostname)

        # Use the IP address to get the location
        location = geolocator.geocode(ip_address)

        if location:
            return location.latitude, location.longitude
        else:
            print("Unable to retrieve location using IP. Defaulting to a predefined location.")
            # Provide a default latitude and longitude here (e.g., your city or a safe location)
            return 12.9716, 77.5977  # Example: Latitude and Longitude of Bangalore, India
    except Exception as e:
        print(f"Error getting location: {e}. Defaulting to a predefined location.")
        # Provide a default latitude and longitude here
        return 12.9716, 77.5977  # Example: Latitude and Longitude of Bangalore, India

# Function to send an SMS alert
def send_alert_message(location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]}"
    for contact in contacts:
        message = client.messages.create(
            body=message_body,
            from_="+12183092954",  # Replace with your Twilio phone number
            to=contact
        )
        print(f"Message sent to {contact}: {message.sid}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()

    try:
        # Attempt to load directly first
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:  # If direct loading fails, try conversion
        try:
            # Convert to WAV using pydub
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        # Use Google Speech Recognition with enhanced settings
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)

        # If show_all=True, command will be a dictionary. Get the most likely transcript.
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None  # If no transcript is found
            print("No transcript found in recognition results.")

        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here

    # Upload audio file
    uploaded = files.upload()
    audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file

    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")  # Print the recognized command

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()

        if user_response == "yes":
            location = get_location()  # Get location automatically
            send_alert_message(location, emergency_contacts)
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
#      <input type="file" id="files-c4e324e7-4cf6-4642-a86a-0d6aaccdfef6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4e324e7-4cf6-4642-a86a-0d6aaccdfef6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket  # Import for IP address lookup


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the device's current location
def get_location():
    """Gets the device's current location using the browser's geolocation API."""
    js_code = """
    async function getLocation() {
      return new Promise((resolve, reject) => {
        navigator.geolocation.getCurrentPosition(
          position => resolve([position.coords.latitude, position.coords.longitude]),
          error => reject(error)
        );
      });
    }
    """
    try:
        location = output.eval_js(js_code + "getLocation()")
        latitude, longitude = location
        print(f"Device location: Latitude: {latitude}, Longitude: {longitude}")
        return latitude, longitude
    except Exception as e:
        print(f"Error getting location: {e}. Defaulting to a predefined location.")
        return 12.9716, 77.5977  # Default location (Bangalore, India)

# Function to send an SMS alert
def send_alert_message(location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]}"
    for contact in contacts:
        message = client.messages.create(
            body=message_body,
            from_="+12183092954",  # Replace with your Twilio phone number
            to=contact
        )
        print(f"Message sent to {contact}: {message.sid}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:  # If direct loading fails, try conversion
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None
    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None  # If no transcript is found
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path = None  # Initialize audio_file_path

    # Check if audio file has already been uploaded
    if not audio_file_path:
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file

    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")  # Print the recognized command

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()

        if user_response == "yes":
            location = get_location()  # Get location automatically
            send_alert_message(location, emergency_contacts)
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
#      <input type="file" id="files-cc8f08db-76ff-4274-a0da-9e83b893d80c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc8f08db-76ff-4274-a0da-9e83b893d80c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket  # Import for IP address lookup


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the device's current location
def get_location():
    """Gets the device's current location using the browser's geolocation API."""
    js_code = """
    async function getLocation() {
      return new Promise((resolve, reject) => {
        navigator.geolocation.getCurrentPosition(
          position => resolve([position.coords.latitude, position.coords.longitude]),
          error => reject(error)
        );
      });
    }
    """
    try:
        location = output.eval_js(js_code + "getLocation()")
        latitude, longitude = location
        print(f"Device location: Latitude: {latitude}, Longitude: {longitude}")
        return latitude, longitude
    except Exception as e:
        print(f"Error getting location: {e}. Defaulting to a predefined location.")
        return 12.9716, 77.5977  # Default location (Bangalore, India)

# Function to send an SMS alert
def send_alert_message(location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]}"
    for contact in contacts:
        message = client.messages.create(
            body=message_body,
            from_="+12183092954",  # Replace with your Twilio phone number
            to=contact
        )
        print(f"Message sent to {contact}: {message.sid}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:  # If direct loading fails, try conversion
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None
    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None  # If no transcript is found
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path = None  # Initialize audio_file_path

    # Check if audio file has already been uploaded
    if not audio_file_path:
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file

    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")  # Print the recognized command

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()

        if user_response == "yes":
            location = get_location()  # Get location automatically
            send_alert_message(location, emergency_contacts)
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
#      <input type="file" id="files-585545bd-fecf-45a0-bb5c-4e7d85b14ee8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-585545bd-fecf-45a0-bb5c-4e7d85b14ee8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket
import os
import requests

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get the device's IP address and location
def get_ip_and_location():
    """Gets the device's public IP address and location using ipapi.co."""
    try:
        # Get public IP address
        response = requests.get("https://api.ipify.org?format=json")
        data = response.json()
        ip_address = data["ip"]
        print(f"Device IP address: {ip_address}")

        # Get location based on IP address
        response = requests.get(f"https://ipapi.co/{ip_address}/json/")
        data = response.json()
        if 'latitude' in data and 'longitude' in data:
            latitude = data['latitude']
            longitude = data['longitude']
            print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
            return ip_address, latitude, longitude
        else:
            print("Unable to retrieve location using ipapi.co.")
            raise Exception("ipapi.co location lookup failed")

    except Exception as e:
        print(f"Error getting IP address or location: {e}")
        print("Defaulting to predefined location.")
        return "N/A", 12.9716, 77.5977  # Example: Default location (Bangalore, India)

# Function to send an SMS alert
def send_alert_message(ip_address, location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)

    # Include IP address in the message body
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[0]},{location[1]} IP Address: {ip_address}"

    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your VERIFIED or PURCHASED Twilio phone number
                to=contact # This number needs to be verified in your Twilio account if you are using a trial account
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# ... (rest of the code remains the same)
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket
import os
import requests

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get location based on user-entered IP address
def get_location():
    while True:
        ip_address = input("Enter the IP address: ")
        try:
            response = requests.get(f"https://ipapi.co/{ip_address}/json/")
            data = response.json()
            if 'latitude' in data and 'longitude' in data:
                latitude = data['latitude']
                longitude = data['longitude']
                print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
                return ip_address, latitude, longitude
            else:
                print("Unable to retrieve location using ipapi.co for the provided IP address.")
        except Exception as e:
            print(f"Error getting location: {e}")
        print("Please enter a valid IP address.")

# Function to send an SMS alert
def send_alert_message(ip_address, location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[1]},{location[2]} IP Address: {ip_address}"
    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your VERIFIED or PURCHASED Twilio phone number
                to=contact
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        # Load directly if possible
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        # Try conversion if direct loading fails
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        # Use Google Speech Recognition with show_all=True for detailed results
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)

        # Extract the most likely transcript from the results
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")

        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")  # Add print statement for debugging
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")  # Add print statement for debugging

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            location = get_location()
            send_alert_message(location[0], location, emergency_contacts)  # Pass IP address and location
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
#      <input type="file" id="files-a015fc4b-54de-439f-a991-e1af7b5d7d69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a015fc4b-54de-439f-a991-e1af7b5d7d69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket
import os
import requests

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get location using public IP address, falling back to manual input
def get_location():
    try:
        # Get public IP address
        response = requests.get("https://api.ipify.org?format=json")
        data = response.json()
        ip_address = data["ip"]
        print(f"Device IP address: {ip_address}")

        # Get location based on IP address
        response = requests.get(f"https://ipapi.co/{ip_address}/json/")
        data = response.json()
        if 'latitude' in data and 'longitude' in data:
            latitude = data['latitude']
            longitude = data['longitude']
            print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
            return ip_address, latitude, longitude
        else:
            print("Unable to retrieve location using ipapi.co for the automatically detected IP address.")
            raise Exception("ipapi.co location lookup failed")

    except Exception as e:
        print(f"Error getting IP address or location: {e}")
        print("Falling back to manual IP address entry.")

        while True:
            ip_address = input("Enter the IP address: ")
            try:
                response = requests.get(f"https://ipapi.co/{ip_address}/json/")
                data = response.json()
                if 'latitude' in data and 'longitude' in data:
                    latitude = data['latitude']
                    longitude = data['longitude']
                    print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
                    return ip_address, latitude, longitude
                else:
                    print("Unable to retrieve location using ipapi.co for the provided IP address.")
            except Exception as e:
                print(f"Error getting location: {e}")
            print("Please enter a valid IP address.")


# Function to send an SMS alert
def send_alert_message(ip_address, location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[1]},{location[2]} IP Address: {ip_address}"
    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your VERIFIED or PURCHASED Twilio phone number
                to=contact
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            location = get_location()
            send_alert_message(location[0], location, emergency_contacts)  # Pass IP address and location
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Device IP address: 34.16.195.21
# Device location (ipapi.co): Latitude: 36.1721, Longitude: -115.1224
# Message sent to +919123144609: SM4da44a8516b243bda6fa32f70de6ac37
# Error sending message to +919036526233: HTTP 400 error: Unable to create record: The number +91903652XXXX is unverified. Trial accounts cannot send messages to unverified numbers; verify +91903652XXXX at twilio.com/user/account/phone-numbers/verified, or purchase a Twilio number to send messages to unverified numbers

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket
import os
import requests
import json

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to send an SMS alert
def send_alert_message(ip_address, location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[1]},{location[2]} IP Address: {ip_address}"
    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your VERIFIED or PURCHASED Twilio phone number
                to=contact
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Function to get location using WPS (wigle.net) and fallback to IP-based geolocation
def get_location():
    try:
        # --- Wi-Fi Positioning (using wigle.net API - Replace with your API key) ---
        # NOTE: This is a conceptual example. You might need to adapt it based on the API documentation.
        wigle_api_key = "YOUR_WIGLE_API_KEY"  # Replace with your actual API key
        wifi_data = {  # Replace with actual Wi-Fi data
            "ssid": "your_wifi_ssid",
            "bssid": "your_wifi_bssid"
        }
        wigle_url = "https://api.wigle.net/api/v2/network/search"
        headers = {
            "Authorization": f"Basic {wigle_api_key}"
        }
        response = requests.post(wigle_url, headers=headers, data=wifi_data)
        print(f"Wigle.net API response: {response.content}")  # Print API response for debugging
        data = response.json()
        if data and data["results"]:
            latitude = data["results"][0]["trilat"]
            longitude = data["results"][0]["trilong"]
            print(f"Device location (WPS): Latitude: {latitude}, Longitude: {longitude}")
            return "WPS", latitude, longitude  # Return location source and coordinates
        else:
            print("Unable to retrieve location using WPS.")

        # --- Fallback to IP-based geolocation (using ipapi.co) ---
        response = requests.get("https://api.ipify.org?format=json")
        data = response.json()
        ip_address = data["ip"]
        print(f"Device IP address: {ip_address}")
        response = requests.get(f"https://ipapi.co/{ip_address}/json/")
        print(f"ipapi.co API response: {response.content}")  # Print API response for debugging
        data = response.json()
        if 'latitude' in data and 'longitude' in data:
            latitude = data['latitude']
            longitude = data['longitude']
            print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
            return ip_address, latitude, longitude  # Return IP address and coordinates
        else:
            print("Unable to retrieve location using ipapi.co for the automatically detected IP address.")
            raise Exception("ipapi.co location lookup failed")

    except Exception as e:
        print(f"Error getting IP address or location: {e}")
        print("Falling back to manual IP address entry.")

        while True:
            ip_address = input("Enter the IP address: ")
            try:
                response = requests.get(f"https://ipapi.co/{ip_address}/json/")
                data = response.json()
                if 'latitude' in data and 'longitude' in data:
                    latitude = data['latitude']
                    longitude = data['longitude']
                    print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
                    return ip_address, latitude, longitude
                else:
                    print("Unable to retrieve location using ipapi.co for the provided IP address.")
            except Exception as e:
                print(f"Error getting location: {e}")
            print("Please enter a valid IP address.")

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            location = get_location()
            send_alert_message(location[0], location, emergency_contacts)  # Pass IP address and location
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Wigle.net API response: b'{"code":415,"message":"HTTP 415 Unsupported Media Type"}'
# Error getting IP address or location: 'results'
# Falling back to manual IP address entry.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-542cc998202f> in <cell line: 141>()
#     163         user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
#     164         if user_response == "yes":
# --> 165             location = get_location()
#     166             send_alert_message(location[0], location, emergency_contacts)  # Pass IP address and location
# ...

# %%
# !pip install twilio

# %%
   from twilio.rest import Client

# %%
def make_call(contacts):
       account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
       auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
       client = Client(account_sid, auth_token)

       for contact in contacts:
           try:
               call = client.calls.create(
                   twiml='<Response><Say>This is an emergency alert. Please respond immediately.</Say></Response>',
                   to=contact,
                   from_="+12183092954"  # Replace with your Twilio phone number
               )
               print(f"Call initiated to {contact}: {call.sid}")
           except Exception as e:
               print(f"Error initiating call to {contact}: {e}")

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import os


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Function to make outgoing calls
def make_call(contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)

    for contact in contacts:
        try:
            call = client.calls.create(
                twiml='<Response><Say>This is an emergency alert. Please respond immediately.</Say></Response>',
                to=contact,
                from_="+12183092954"  # Replace with your Twilio phone number
            )
            print(f"Call initiated to {contact}: {call.sid}")
        except Exception as e:
            print(f"Error initiating call to {contact}: {e}")

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to make a call? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            make_call(emergency_contacts)  # Make calls to emergency contacts
            speak("Calls initiated to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Call initiated to +919123144609: CAf5a61ad912774d0389d55c14823cca5f
# Error initiating call to +919036526233: HTTP 400 error: Unable to create record: The number +919036526233 is unverified. Trial accounts may only make calls to verified numbers.

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import os


# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Function to send pre-recorded video link via SMS
def send_video_link(contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    video_link = "YOUR_VIDEO_URL"  # Replace with your pre-recorded video URL

    message_body = f"Emergency Alert! Video message: {video_link}"
    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your Twilio phone number
                to=contact
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            send_video_link(emergency_contacts)  # Send video link to emergency contacts
            speak("Alert sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Message sent to +919123144609: SM78c406f0f827e3522a8b5c04a95405d0
# Error sending message to +919036526233: HTTP 400 error: Unable to create record: The number +91903652XXXX is unverified. Trial accounts cannot send messages to unverified numbers; verify +91903652XXXX at twilio.com/user/account/phone-numbers/verified, or purchase a Twilio number to send messages to unverified numbers

# %%
# !pip install webbrowser
# Out:
# ERROR: Could not find a version that satisfies the requirement webbrowser (from versions: none)
# ERROR: No matching distribution found for webbrowser

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests
# !pip install webbrowser

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import os
import webbrowser

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

def initiate_video_call(contacts):
    jitsi_meet_url = "https://meet.jit.si/your-meeting-room"  # Replace with your Jitsi Meet room URL
    print(f"Initiating video call: {jitsi_meet_url}")  # Print for debugging

    try:
        # Try specifying a specific browser (e.g., Chrome)
        chrome_path = '/usr/bin/google-chrome'  # Path to Chrome executable
        webbrowser.register('chrome', None, webbrowser.BackgroundBrowser(chrome_path))
        webbrowser.get('chrome').open_new_tab(jitsi_meet_url)

    except Exception as e:
        print(f"Error opening video call: {e}")
        print(f"Please manually join the video call: {jitsi_meet_url}")

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to initiate a video call? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            initiate_video_call(emergency_contacts)  # Initiate video call
            speak("Video call initiated.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# ERROR: Could not find a version that satisfies the requirement webbrowser (from versions: none)
# ERROR: No matching distribution found for webbrowser
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Initiating video call: https://meet.jit.si/your-meeting-room

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests
# !pip install webbrowser

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr # This line was causing the error
import pyttsx3
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import os
import webbrowser

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

def initiate_video_call(contacts):
    jitsi_meet_url = "https://meet.jit.si/your-meeting-room"  # Replace with your Jitsi Meet room URL
    print(f"Initiating video call: {jitsi_meet_url}")  # Print for debugging

    try:
        # Try specifying a specific browser (e.g., Chrome)
        chrome_path = '/usr/bin/google-chrome'  # Path to Chrome executable
        webbrowser.register('chrome', None, webbrowser.BackgroundBrowser(chrome_path))
        webbrowser.get('chrome').open_new_tab(jitsi_meet_url)

    except Exception as e:
        print(f"Error opening video call: {e}")
        print(f"Please manually join the video call: {jitsi_meet_url}")

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to initiate a video call? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            initiate_video_call(emergency_contacts)  # Initiate video call
            speak("Video call initiated.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# ERROR: Could not find a version that satisfies the requirement webbrowser (from versions: none)
# ERROR: No matching distribution found for webbrowser
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Initiating video call: https://meet.jit.si/your-meeting-room

# %%
# !pip install speech_recognition
# Out:
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip cache purge
# Out:
# Files removed: 58

# %%
# !pip install speech_recognition -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !sudo apt-get install libportaudio2  # Install portaudio dependency
# !pip install pyaudio --no-binary :all:  # Force installation from source
# !pip install speech_recognition
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libportaudio2 is already the newest version (19.6.0-1.1).
# libportaudio2 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ...

# %%
# !pip install SpeechRecognition pyaudio geopy twilio pyttsx3
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)

# %%
# !pip install SpeechRecognition pyaudio geopy twilio pyttsx3 pydub opencv-python-headless
# !pip install streamlit pyngrok

import speech_recognition as sr
import pyttsx3
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.4 MB/s eta 0:00:00
# ...

# %%
# !pip install SpeechRecognition pyaudio geopy twilio pyttsx3 pydub opencv-python-headless
    # !pip install streamlit pyngrok
# Out:
#   File "<ipython-input-33-b62897f65d3b>", line 2
#     get_ipython().system('pip install streamlit pyngrok')
#     ^
# IndentationError: unexpected indent

# %%
# !pip install ipywebrtc
# !pip install speech_recognition
# !pip install pyttsx3
# !pip install geopy
# !pip install twilio
# !pip install pydub
# !pip install requests

import IPython
from google.colab import output
import base64
import time
import speech_recognition as sr
import pyttsx3
from geopy.geocoders import Nominatim
from twilio.rest import Client
from google.colab import files
from pydub import AudioSegment
import socket
import os
import requests
import json

# Text-to-speech initialization
def speak(message):
    engine = pyttsx3.init('espeak')  # Use espeak engine
    engine.say(message)
    engine.runAndWait()

# Function to get location using public IP address, falling back to predefined location
def get_location():
    try:
        # Get public IP address
        response = requests.get("https://api.ipify.org?format=json")
        data = response.json()
        ip_address = data["ip"]
        print(f"Device IP address: {ip_address}")

        response = requests.get(f"https://ipapi.co/{ip_address}/json/")
        data = response.json()
        if 'latitude' in data and 'longitude' in data:
            latitude = data['latitude']
            longitude = data['longitude']
            print(f"Device location (ipapi.co): Latitude: {latitude}, Longitude: {longitude}")
            return ip_address, latitude, longitude
        else:
            print("Unable to retrieve location using ipapi.co for the automatically detected IP address.")
            raise Exception("ipapi.co location lookup failed")

    except Exception as e:
        print(f"Error getting IP address or location: {e}")
        print("Falling back to predefined location.")

        # Predefined location for Dayananda Sagar University, Harohalli:
        latitude = 12.7980
        longitude = 77.2744
        ip_address = "N/A"  # IP address is not relevant in this case
        print(f"Using predefined location: Latitude: {latitude}, Longitude: {longitude}")
        return ip_address, latitude, longitude


# Function to send an SMS alert
def send_alert_message(ip_address, location, contacts):
    account_sid = "AC9be8ea651078164b7a547c94df319c3b"  # Replace with your Account SID
    auth_token = "79895e0e72041f1c573064d555404a09"  # Replace with your Auth Token
    client = Client(account_sid, auth_token)
    message_body = f"Emergency Alert! Immediate help required. Location: https://www.google.com/maps?q={location[1]},{location[2]} IP Address: {ip_address}"
    for contact in contacts:
        try:
            message = client.messages.create(
                body=message_body,
                from_="+12183092954",  # Replace with your VERIFIED or PURCHASED Twilio phone number
                to=contact
            )
            print(f"Message sent to {contact}: {message.sid}")
        except Exception as e:
            print(f"Error sending message to {contact}: {e}")

# Function to detect the voice command from an uploaded audio file
def detect_voice_command_from_file(audio_file_path):
    recognizer = sr.Recognizer()
    try:
        with sr.AudioFile(audio_file_path) as source:
            audio = recognizer.record(source)
    except Exception:
        try:
            sound = AudioSegment.from_file(audio_file_path)
            sound.export("temp_audio.wav", format="wav")
            with sr.AudioFile("temp_audio.wav") as source:
                audio = recognizer.record(source)
        except Exception as e:
            print(f"Error: Could not read or convert audio file: {e}")
            return None

    try:
        command = recognizer.recognize_google(audio, language="en-US", show_all=True)
        if isinstance(command, dict) and "alternative" in command and command["alternative"]:
            command = command["alternative"][0]["transcript"].lower()
        else:
            command = None
            print("No transcript found in recognition results.")
        return command
    except sr.UnknownValueError:
        print("Could not understand audio")
        return None
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return None

# Main program
if __name__ == "__main__":
    emergency_contacts = ["+919123144609", "+919036526233"]  # Add your emergency contacts here
    audio_file_path_file = "audio_file_path.txt"  # File to store the audio file path

    # Check if audio file path is stored in the file
    if os.path.exists(audio_file_path_file):
        with open(audio_file_path_file, "r") as f:
            audio_file_path = f.read().strip()
    else:
        # Upload audio file and store the path in the file
        uploaded = files.upload()
        audio_file_path = list(uploaded.keys())[0]  # Get the path of the uploaded file
        with open(audio_file_path_file, "w") as f:
            f.write(audio_file_path)

    print("Before detect_voice_command_from_file")
    command = detect_voice_command_from_file(audio_file_path)
    print(f"Recognized command: {command}")

    # Check for the corrected trigger phrase "help me"
    if command == "help me":
        speak("Help command detected. Do you want to send an alert message? Say yes.")
        user_response = input("Type 'yes' to confirm or 'no' to cancel: ").strip().lower()
        if user_response == "yes":
            location = get_location()
            send_alert_message(location[0], location, emergency_contacts)  # Pass IP address and location
            speak("Alert message sent to your emergency contacts.")
        else:
            speak("Alert canceled.")
    else:
        speak("No valid help command detected.")
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition
# ...
# Before detect_voice_command_from_file
# Recognized command: help me
# Type 'yes' to confirm or 'no' to cancel: yes
# Device IP address: 34.16.195.21
# Unable to retrieve location using ipapi.co for the automatically detected IP address.
# Error getting IP address or location: ipapi.co location lookup failed
# Falling back to predefined location.
# Using predefined location: Latitude: 12.798, Longitude: 77.2744
# Message sent to +919123144609: SMefc704c385afe8f960fb22a8ba9717c1
# Error sending message to +919036526233: HTTP 400 error: Unable to create record: The number +91903652XXXX is unverified. Trial accounts cannot send messages to unverified numbers; verify +91903652XXXX at twilio.com/user/account/phone-numbers/verified, or purchase a Twilio number to send messages to unverified numbers
